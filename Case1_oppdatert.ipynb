# %% [markdown]
# # Mappeoppgave 1
# ## <u>Beskrivelse
# Les oppgaveteksten nøye. Se hvordan man leverer oppgaven <th><a href='https://uit-sok-1003-h22.github.io/semesteroppgave.html'>her</a> </th> og  <th><a href='https://uit-sok-1003-h22.github.io/github.html'>her</a>. Husk at den skal leveres både som jupyter-fil og som PDF. Kommenter kodene du skriver i alle oppgaver og vær nøye på å definere aksene mm i figurer. I noen av oppgavetekstene står det hint, men det betyr ikke at de ikke kan løses på andre måter
#
# ##### For å hente denne filen til Jupyter gjør du slik:
#
# <ol>
# <li>Åpne et "terminalvindu"
# <li>Gå til hjemmeområdet ditt
#
#
#     [user@jupty02 ~]$ cd
# <li>Lag en ny mappe på ditt hjemmeområde ved å skrive inn i terminalvinduet
#
#     [user@jupty02 ~]$ mkdir SOK-1003-eksamen-2022-mappe1
#
# <li>Gå så inn i den mappen du har laget ved å skrive
#
#     [user@jupty02 ~]$ cd SOK-1003-eksamen-2022-mappe1
# <li> Last ned kursmateriellet ved å kopiere inn følgende kommando i kommandovinduet:
#
#     [user@jupty02 sok-1003]$ git clone https://github.com/uit-sok-1003-h22/mappe/
# </ol>
# <br> Oppgi gruppenavn m/ medlemmer på epost ole.k.aars@uit.no innen 7/10, så blir dere satt opp til tidspunkt for presentasjon 19/10.
# <br>Bruk så denne filen til å gjøre besvarelsen din. Ved behov; legg til flere celler ved å trykke "b"
# </br>
# <hr>

# %%
GRUPPE(solo) - SONDRE HANSEN

# %% [markdown]
# ## <u> Oppgavene
#
# ### Oppgave 1 (5 poeng)
# a) Lag en kort fortelling i en python kode som inkluderer alle de fire typer variabler vi har lært om i kurset. Koden skal kunne kjøres med print(). Koden burde inneholde utregninger av elementer du har definert

# %%
print(f"there was once a little number named {1} and he knew he always was {'right'} since he was 1, a whole, compleat and never {0.5} or {1.5} he was 1 he was {True}")
# Out:
# there was once a little number named 1 and he knew he always was right since he was 1, a whole, compleat and never 0.5 or 1.5 he was 1 he was True

# %%
# importing and matplotlib theme

import random
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
import sympy as sy
from cycler import cycler

# custome plot style
params  = {
"lines.linewidth": 1.5,

"legend.fancybox": "true",

"axes.prop_cycle": cycler('color', ["#ffa822","#1ac0c6","#ff6150"]),
"axes.facecolor": "#2b2b2b",
"axes.axisbelow": "true",
"axes.grid": "true",
"axes.edgecolor": "#2b2b2b",
"axes.linewidth": 0.5,
"axes.labelpad": 0,

"patch.edgecolor": "#2b2b2b",
"patch.linewidth": 0.5,

"grid.linestyle": "--",
"grid.linewidth": 0.5,
"grid.color": "#b8aba7",

"xtick.major.size": 0,
"xtick.minor.size": 0,
"ytick.major.size": 0,
"ytick.minor.size": 0,

"font.family":"monospace",
"font.size":10.0,
"text.color": "#FFE9E3",
"axes.labelcolor": "#b8aba7",
"xtick.color": "#b8aba7",
"ytick.color": "#b8aba7",

"savefig.edgecolor": "#2b2b2b",
"savefig.facecolor": "#2b2b2b",

"figure.subplot.left": 0.08,
"figure.subplot.right": 0.95,
"figure.subplot.bottom": 0.09,
"figure.facecolor": "#2b2b2b"}

pylab.rcParams.update(params)
print("finish")
# Out:
# finish

# %% [markdown]
# ### Oppgave 2 (10 poeng)

# %% [markdown]
# Leieprisene i landet har steget de siste månedene. Ved å bruke realistiske tall<br>
# a) Lag tilbuds og etterspørselsfunksjoner for leie av bolig (Bruk av ikke-lineære funksjoner belønnes). <br>
#  <br> Definer funksjonene slik at det er mulig å finne en likevekt

# %%
price_decline = 0.8 #12% price increas in areal

def demand(x):
    #Need to be fixed, I do not know if this is "realistiske tall"
    return -0.1*x**2+45*x+8500
    
def supply(x):
    #Need to be fixed, I do not know if this is "realistiske tall"
    return -50*x+20000

x = np.linspace(0,250,100) # Amount of Houses on Marked 0 to 250

# %% [markdown]
# b) Vis at disse er henholdvis fallende og stigende, ved bruk av
# - Regning
# - figurativt (matplotlib)
# Husk å markere aksene tydelig og at funskjonene er definert slik at linjene krysser

# %%
plt.figure(figsize=(10,5))
plt.suptitle("Rent Price for apartment",x=0.13,y=0.98,size=14,weight='bold')
plt.title("Price vs Quantity",loc="left",size=10)
plt.plot(x,supply(x),label='Tilbud')
plt.plot(x,demand(x),color='green',label='Etterspørsel')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),ncol=5)

plt.ylabel('Price')
plt.xlabel('Amount of Houses on Marked')
# Out:
# Text(0.5, 0, 'Amount of Houses on Marked')

# %% [markdown]
# c) Kommenter funksjonene og likevekten. Vis gjerne figurativt hvor likevekten er ved bruk av scatter

# %%
plt.figure(figsize=(10,5))
plt.suptitle("Rent Price for apartment",x=0.13,y=0.98,size=14,weight='bold')
plt.title("Price vs Quantity",loc="left",size=10)
plt.plot(x,supply(x),label='Tilbud')
plt.plot(x,demand(x),color='green',label='Etterspørsel')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),ncol=5)

plt.ylabel('Price')
plt.xlabel('Amount of Houses on Marked')

# solve equilibrium with sympy
q = sy.Symbol('q')
eq = sy.Eq(supply(q), demand(q))
plt.scatter(sy.solve(eq)[0],demand(sy.solve(eq)[0]),zorder=2)

# %% [markdown]
# ### Oppgave 3 (15 poeng)

# %% [markdown]
# SSB har omfattende data på befolkningsutvikling (https://www.ssb.no/statbank/table/05803/tableViewLayout1/). Disse dataene skal du bruke i de neste deloppgavene.
#
# a) lag lister av følgende variabler: "Befolkning 1. januar", "Døde i alt", "Innflyttinger" og "Utflyttinger". Velg selv variabelnavn når du definerer dem i python. Første element i hver liste skal være variabelnavnet. Bruk tall for perioden 2012-2021. Lag så en liste av disse listene. Du kan kalle den "ssb".
# <br><br>
# <b>Hint:</b> når du skal velge variabler på SSB sin nettside må du holde inne ctrl for å velge flere variabler.

# %%
# import
from pyjstat import pyjstat
import requests

# collect data
POST_URL  = "https://data.ssb.no/api/v0/no/table/05803/"

payload  = {
  "query": [
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "Personer",
          "Dode",
          "Innflyttinger",
          "Utflyttinger"
        ]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "item",
        "values": [
          "2012",
          "2013",
          "2014",
          "2015",
          "2016",
          "2017",
          "2018",
          "2019",
          "2020",
          "2021",
          "2022"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

resultat = requests.post(POST_URL, json = payload)
dataset = pyjstat.Dataset.read(resultat.text)
df = dataset.write('dataframe')
print(df)
# Out:
#       statistikkvariabel    år      value
# 0   Befolkning 1. januar  2012  4985870.0
# 1   Befolkning 1. januar  2013  5051275.0
# 2   Befolkning 1. januar  2014  5109056.0
# 3   Befolkning 1. januar  2015  5165802.0
# 4   Befolkning 1. januar  2016  5213985.0
# 5   Befolkning 1. januar  2017  5258317.0
# 6   Befolkning 1. januar  2018  5295619.0
# 7   Befolkning 1. januar  2019  5328212.0
# 8   Befolkning 1. januar  2020  5367580.0
# 9   Befolkning 1. januar  2021  5391369.0
# 10  Befolkning 1. januar  2022  5425270.0
# 11            Døde i alt  2012    41992.0
# 12            Døde i alt  2013    41282.0
# 13            Døde i alt  2014    40394.0
# 14            Døde i alt  2015    40727.0
# 15            Døde i alt  2016    40726.0
# 16            Døde i alt  2017    40774.0
# 17            Døde i alt  2018    40840.0
# 18            Døde i alt  2019    40684.0
# 19            Døde i alt  2020    40611.0
# 20            Døde i alt  2021    42002.0
# 21            Døde i alt  2022        NaN
# 22         Innflyttinger  2012    78570.0
# 23         Innflyttinger  2013    75789.0
# 24         Innflyttinger  2014    70030.0
# 25         Innflyttinger  2015    67276.0
# 26         Innflyttinger  2016    66800.0
# 27         Innflyttinger  2017    58192.0
# 28         Innflyttinger  2018    52485.0
# 29         Innflyttinger  2019    52153.0
# 30         Innflyttinger  2020    38071.0
# 31         Innflyttinger  2021    53947.0
# 32         Innflyttinger  2022        NaN
# 33          Utflyttinger  2012    31227.0
# 34          Utflyttinger  2013    35716.0
# 35          Utflyttinger  2014    31875.0
# 36          Utflyttinger  2015    37474.0
# 37          Utflyttinger  2016    40724.0
# 38          Utflyttinger  2017    36843.0
# 39          Utflyttinger  2018    34382.0
# 40          Utflyttinger  2019    26826.0
# 41          Utflyttinger  2020    26744.0
# 42          Utflyttinger  2021    34297.0
# 43          Utflyttinger  2022        NaN

# %%
from math import nan, isnan

befolkning_1_januar = ["befolkning_1_januar"]
dead_alt = ["dead_alt"]
innflyttinger = ["innflyttinger"]
Utflyttinger = ["Utflyttinger"]
year = ["year"]
year.extend([year for year in range(2012, 2023)])

def create_list(list,filter):
    for f,value in zip(df.statistikkvariabel,df.value):
        if str(filter) == str(f):
            if isnan(value): # convert NaN to 0, tried to use some build in functions, but non worked.
                value = 0
            list.append(value)


create_list(befolkning_1_januar,"Befolkning 1. januar")
create_list(dead_alt,"Døde i alt")
create_list(innflyttinger,"Innflyttinger")
create_list(Utflyttinger,"Utflyttinger")

print(f"year : {year}")
print(f"befolkning_1_januar : {befolkning_1_januar}")
print(f"dead_alt : {dead_alt}")
print(f"innflyttinger : {innflyttinger}")
print(f"Utflyttinger : {Utflyttinger}")
print("\n","="*8,"\n")

ssb = [year,befolkning_1_januar,dead_alt,innflyttinger,Utflyttinger]
print(ssb)
# Out:
# year : ['year', 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# befolkning_1_januar : ['befolkning_1_januar', 4985870.0, 5051275.0, 5109056.0, 5165802.0, 5213985.0, 5258317.0, 5295619.0, 5328212.0, 5367580.0, 5391369.0, 5425270.0]
# dead_alt : ['dead_alt', 41992.0, 41282.0, 40394.0, 40727.0, 40726.0, 40774.0, 40840.0, 40684.0, 40611.0, 42002.0, 0]
# innflyttinger : ['innflyttinger', 78570.0, 75789.0, 70030.0, 67276.0, 66800.0, 58192.0, 52485.0, 52153.0, 38071.0, 53947.0, 0]
# Utflyttinger : ['Utflyttinger', 31227.0, 35716.0, 31875.0, 37474.0, 40724.0, 36843.0, 34382.0, 26826.0, 26744.0, 34297.0, 0]
#
#  ========
#
# [['year', 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022], ['befolkning_1_januar', 4985870.0, 5051275.0, 5109056.0, 5165802.0, 5213985.0, 5258317.0, 5295619.0, 5328212.0, 5367580.0, 5391369.0, 5425270.0], ['dead_alt', 41992.0, 41282.0, 40394.0, 40727.0, 40726.0, 40774.0, 40840.0, 40684.0, 40611.0, 42002.0, 0], ['innflyttinger', 78570.0, 75789.0, 70030.0, 67276.0, 66800.0, 58192.0, 52485.0, 52153.0, 38071.0, 53947.0, 0], ['Utflyttinger', 31227.0, 35716.0, 31875.0, 37474.0, 40724.0, 36843.0, 34382.0, 26826.0, 26744.0, 34297.0, 0]]

# %% [markdown]
# b) konverter "ssb" til en numpy matrise og gi den et nytt navn

# %%
# unsure if you are asking for a matrix or a multi dimensional array
# matrix
ssb_np_matrix = np.matrix(ssb)
print("MATRIX")
print(type(ssb_np_matrix))
print(ssb_np_matrix)

print("\n","="*20,"\n")
# array
ssb_np_array = np.array(ssb)
print("ARRAY")
print(type(ssb_np_array))
print(ssb_np_array)
# Out:
# MATRIX
# <class 'numpy.matrix'>
# [['year' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019' '2020'
#   '2021' '2022']
#  ['befolkning_1_januar' '4985870.0' '5051275.0' '5109056.0' '5165802.0'
#   '5213985.0' '5258317.0' '5295619.0' '5328212.0' '5367580.0' '5391369.0'
#   '5425270.0']
#  ['dead_alt' '41992.0' '41282.0' '40394.0' '40727.0' '40726.0' '40774.0'
#   '40840.0' '40684.0' '40611.0' '42002.0' '0']
#  ['innflyttinger' '78570.0' '75789.0' '70030.0' '67276.0' '66800.0'
#   '58192.0' '52485.0' '52153.0' '38071.0' '53947.0' '0']
#  ['Utflyttinger' '31227.0' '35716.0' '31875.0' '37474.0' '40724.0'
#   '36843.0' '34382.0' '26826.0' '26744.0' '34297.0' '0']]
#
#  ====================
#
# ARRAY
# <class 'numpy.ndarray'>
# [['year' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019' '2020'
#   '2021' '2022']
#  ['befolkning_1_januar' '4985870.0' '5051275.0' '5109056.0' '5165802.0'
#   '5213985.0' '5258317.0' '5295619.0' '5328212.0' '5367580.0' '5391369.0'
#   '5425270.0']
#  ['dead_alt' '41992.0' '41282.0' '40394.0' '40727.0' '40726.0' '40774.0'
#   '40840.0' '40684.0' '40611.0' '42002.0' '0']
#  ['innflyttinger' '78570.0' '75789.0' '70030.0' '67276.0' '66800.0'
#   '58192.0' '52485.0' '52153.0' '38071.0' '53947.0' '0']
#  ['Utflyttinger' '31227.0' '35716.0' '31875.0' '37474.0' '40724.0'
#   '36843.0' '34382.0' '26826.0' '26744.0' '34297.0' '0']]

# %% [markdown]
# c) Putt alle tallene inn i en egen matrise og konverter disse til int

# %%
# unsure if you are asking for a matrix or a multi dimensional array
# NOTE: convertion of NaN to 0 is because NaN can not be converted to INT
# matrix
year_matrix = np.matrix(ssb_np_matrix[0,1:-1],int)
befolkning_1_januar_matrix = np.matrix(np.float_(ssb_np_matrix[1,1:-1]),int)
dead_alt_matrix = np.matrix(np.float_(ssb_np_matrix[2,1:-1]),int)
innflyttinger_matrix = np.matrix(np.float_(ssb_np_matrix[3,1:-1]),int)
Utflyttinger_matrix = np.matrix(np.float_(ssb_np_matrix[4,1:-1]),int)

print("MATRIX")

print(f"year_matrix: {type(year_matrix)}\n{year_matrix}\n")
print(f"befolkning_1_januar_matrix: {type(befolkning_1_januar_matrix)}\n{befolkning_1_januar_matrix}\n")
print(f"year_matrix: {type(dead_alt_matrix)}\n{dead_alt_matrix}\n")
print(f"dead_alt_matrix: {type(innflyttinger_matrix)}\n{innflyttinger_matrix}\n")
print(f"Utflyttinger_matrix: {type(Utflyttinger_matrix)}\n{Utflyttinger_matrix}\n")
print("-"*20)
print(f"ssb_matrix: {type(ssb_np_matrix)}\n{ssb_np_matrix}")
print("-"*20)

print("\n","="*20,"\n")

# array
year_array = np.array(ssb_np_array[0,1:-1],int)
befolkning_1_januar_array = np.array(np.float_(ssb_np_array[1,1:-1]),int)
dead_alt_array = np.array(np.float_(ssb_np_array[2,1:-1]),int)
innflyttinger_array = np.array(np.float_(ssb_np_array[3,1:-1]),int)
Utflyttinger_array = np.array(np.float_(ssb_np_array[4,1:-1]),int)

print("ARRAY")

print(f"year_array: {type(year_array)}\n{year_array}\n")
print(f"befolkning_1_januar_array: {type(befolkning_1_januar_array)}\n{befolkning_1_januar_array}\n")
print(f"dead_alt_array: {type(dead_alt_array)}\n{dead_alt_array}\n")
print(f"innflyttinger_array: {type(innflyttinger_array)}\n{innflyttinger_array}\n")
print(f"Utflyttinger_array: {type(Utflyttinger_array)}\n{Utflyttinger_array}\n")
print("-"*20)
print(f"ssb_matrix: {type(ssb_np_array)}\n{ssb_np_array}")
print("-"*20)
# Out:
# MATRIX
# year_matrix: <class 'numpy.matrix'>
# [[2012 2013 2014 2015 2016 2017 2018 2019 2020 2021]]
#
# befolkning_1_januar_matrix: <class 'numpy.matrix'>
# [[4985870 5051275 5109056 5165802 5213985 5258317 5295619 5328212 5367580
#   5391369]]
#
# year_matrix: <class 'numpy.matrix'>
# [[41992 41282 40394 40727 40726 40774 40840 40684 40611 42002]]
#
# dead_alt_matrix: <class 'numpy.matrix'>
# [[78570 75789 70030 67276 66800 58192 52485 52153 38071 53947]]
#
# Utflyttinger_matrix: <class 'numpy.matrix'>
# [[31227 35716 31875 37474 40724 36843 34382 26826 26744 34297]]
#
# --------------------
# ssb_matrix: <class 'numpy.matrix'>
# [['year' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019' '2020'
#   '2021' '2022']
#  ['befolkning_1_januar' '4985870.0' '5051275.0' '5109056.0' '5165802.0'
#   '5213985.0' '5258317.0' '5295619.0' '5328212.0' '5367580.0' '5391369.0'
#   '5425270.0']
#  ['dead_alt' '41992.0' '41282.0' '40394.0' '40727.0' '40726.0' '40774.0'
#   '40840.0' '40684.0' '40611.0' '42002.0' '0']
#  ['innflyttinger' '78570.0' '75789.0' '70030.0' '67276.0' '66800.0'
#   '58192.0' '52485.0' '52153.0' '38071.0' '53947.0' '0']
#  ['Utflyttinger' '31227.0' '35716.0' '31875.0' '37474.0' '40724.0'
#   '36843.0' '34382.0' '26826.0' '26744.0' '34297.0' '0']]
# --------------------
#
#  ====================
#
# ARRAY
# year_array: <class 'numpy.ndarray'>
# [2012 2013 2014 2015 2016 2017 2018 2019 2020 2021]
#
# befolkning_1_januar_array: <class 'numpy.ndarray'>
# [4985870 5051275 5109056 5165802 5213985 5258317 5295619 5328212 5367580
#  5391369]
#
# dead_alt_array: <class 'numpy.ndarray'>
# [41992 41282 40394 40727 40726 40774 40840 40684 40611 42002]
#
# innflyttinger_array: <class 'numpy.ndarray'>
# [78570 75789 70030 67276 66800 58192 52485 52153 38071 53947]
#
# Utflyttinger_array: <class 'numpy.ndarray'>
# [31227 35716 31875 37474 40724 36843 34382 26826 26744 34297]
#
# --------------------
# ssb_matrix: <class 'numpy.ndarray'>
# [['year' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019' '2020'
#   '2021' '2022']
#  ['befolkning_1_januar' '4985870.0' '5051275.0' '5109056.0' '5165802.0'
#   '5213985.0' '5258317.0' '5295619.0' '5328212.0' '5367580.0' '5391369.0'
#   '5425270.0']
#  ['dead_alt' '41992.0' '41282.0' '40394.0' '40727.0' '40726.0' '40774.0'
#   '40840.0' '40684.0' '40611.0' '42002.0' '0']
#  ['innflyttinger' '78570.0' '75789.0' '70030.0' '67276.0' '66800.0'
#   '58192.0' '52485.0' '52153.0' '38071.0' '53947.0' '0']
#  ['Utflyttinger' '31227.0' '35716.0' '31875.0' '37474.0' '40724.0'
#   '36843.0' '34382.0' '26826.0' '26744.0' '34297.0' '0']]
# --------------------

# %% [markdown]
# d) vis befolkningsutviklingen grafisk for de gjeldene årene ved bruk av matplotlib, og mer spesifikt "fig, ax = plt.subplots()". Vis befolkning på y-aksen i millioner

# %%
print(year_array)
print(year_matrix)

plt.figure(figsize=(10,5))
plt.plot(year_array,befolkning_1_januar_array*10**-6)
plt.suptitle("befolkningsutviklingen",x=0.13,y=0.95,size=14,weight='bold')
plt.title("year - (2012-2022)",loc="left",size=10)
plt.subplots_adjust(top=0.85)
plt.xlabel("year")
plt.ylabel("befolkning [MILLION]")
plt.ticklabel_format(style='plain')
# Out:
# [2012 2013 2014 2015 2016 2017 2018 2019 2020 2021]
# [[2012 2013 2014 2015 2016 2017 2018 2019 2020 2021]]

# %% [markdown]
# e) Lag det samme plottet ved bruk av oppslag. Hva er fordelen med dette?

# %%
df_map = {
    "YEAR":year_array,
    "BEFOLKNING":befolkning_1_januar_array,
    "DEAD":dead_alt_array,
    "INNFLYTTING":innflyttinger_array,
    "UTFLYTTING":Utflyttinger_array}

plt.figure(figsize=(10,5))
plt.plot(df_map["YEAR"],df_map["BEFOLKNING"]*10**-6)
plt.suptitle("befolkningsutviklingen",x=0.13,y=0.95,size=14,weight='bold')
plt.title("year - (2012-2022)",loc="left",size=10)
plt.subplots_adjust(top=0.85)
plt.xlabel("year")
plt.ylabel("befolkning [MILLION]")
plt.ticklabel_format(style='plain')

# fordelen i aa bruke et Dictionary, Hashmap heller bare Map er at det blir mer organisert(mindre variabler aa holde styr paa)
# Med storre databaser saa e et map raskere i noen ting, foreksempel en for loop

# %% [markdown]
# f) Hva er den relative befolkningstilveksten utenom fødsler (dvs. innvandring/utvandring)? Definer en ny array og legg den til i oppslaget du laget i oppgaven tidligere. Kall den "rel_immigration". Plot denne sammen med grafen du laget i (d).

# %%
from matplotlib import cbook

df_map["rel_immigration"] = np.array(np.subtract(innflyttinger_array,Utflyttinger_array))

print(df_map["rel_immigration"])

plt.subplots(figsize=(10,5))
plt.plot(df_map["YEAR"],df_map["BEFOLKNING"],label="BEFOLKNING")
plt.plot(df_map["YEAR"],df_map["rel_immigration"],label="rel immigration")
plt.suptitle("befolkningsutviklingen",x=0.13,y=0.95,size=14,weight='bold')
plt.title("year - (2012-2022)",loc="left",size=10)
plt.subplots_adjust(top=0.85)
plt.xlabel("year")
plt.ylabel("befolkning [MILLION] - log")
plt.yscale("log",base = 10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),ncol=5)
# Out:
# [47343 40073 38155 29802 26076 21349 18103 25327 11327 19650]

# %% [markdown]
# g) ekstrapoeng. Kan plotte de samme tallene (dvs "rel_immigration" og "befolkning" sammen med år) i to figurer ved siden av hverandre ved bruk av "fig, (ax1, ax2) = plt.subplots(1, 2)". Gi grafene ulik farge

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))

ax1.set_title("befolkningsutviklingen",size=14,weight='bold')
ax2.set_title("REL IMMIGRATION",size=14,weight='bold')
ax1.set_ylabel('befolkning [MILLION]')
ax2.set_ylabel('befolkning [thousand]')
ax1.set_xlabel('YEAR')
ax2.set_xlabel('YEAR')
ax1.ticklabel_format(style='plain')


ax1.plot(df_map["YEAR"], df_map["BEFOLKNING"]*10**-6)
ax2.plot(df_map["YEAR"], df_map["rel_immigration"]*10**-3,color="#1ac0c6")

# %% [markdown]
# ## Oppgave 4 (20 poeng)

# %% [markdown]
# Et lån består som regel av et månedlig terminbeløp. Dette beløpet er summen av avdrag (nedbetalingen på lånet) og renter. Vi antar månedlig forrenting i alle oppgavene. Dvs. at det er 12 terminer i hvert år.<br><br>
# a) Lag en funksjon som regner ut hvor mye lånet "x" koster deg i renteutgifter for "t" terminer med årlig rente "r" for et serielån. <br> <br>  Siden dette er et serielån, så vil avdragene være like hver måned men renteutgiftene reduseres i takt med avdragene. Renteutgiftene for en gitt termin "t" vil derfor være den årlige renten "r" (delt på antall forrentinger "f") på gjenværende beløp på det tidspunktet.   $renteutgifter_{t} = (x-a*(t-1))*{r/f}$   <br>  <br>
# Det vil si at renteutgiftene første termin er <br>
# $renteutgifter_{1} = (x-a*0)*{r/f}$, og andre termin er <br>
# $renteutgifter_{2} = (x-a*1)*{r/f}$ osv..<br> <br>
# Siden vi er ute etter den totale kostnaden i svaret, må du summere renteutgiftene over alle terminer, det vil si $\sum_{t=1}^N(x-a*(t-1))*{r/f}$. Dette betyr egentlig bare $renteutgifter_{1} + renteutgifter_{2},...,+renteutgifter_{t}$
#
#
# <br>
# <b>Hint:</b> siden terminbeløpet varierer for hver måned (pga at rentene endres), må alle enkeltperioder summeres. Det kan være nyttige å bruke funksjonen np.arange() til dette. Mao, det er ikke nødvendig å bruke sigma ($\sum_{t=1}^N$) i formelen til dette

# %%
def renteutgifter(loan:int,rente:float,terminer:int,rente_format:str="desimal"):
    if rente_format == "percent" or rente_format == "%":
        rente = rente/100
    avdragsbeløp = loan/terminer
    rentesats  = rente/12
    rentebeløp = loan*rentesats
    terminbeløp = avdragsbeløp+rentebeløp
    rente_list = []
    termin_list = []
    
    for termin in range(1,terminer+1):
        current_value = (loan - avdragsbeløp*(termin-1))
        rente_list.append(current_value*rentesats)
        termin_list.append(rente_list[-1]+avdragsbeløp)
        
    data = {"Input Data": f"\n------\nloan: {loan}\nrente: {int((rente)*100)}%\nterminer: {terminer}\n",
        "Avdrag":avdragsbeløp,"Rentesats":rentesats,"Rente":rente_list,"Termin":termin_list}
    return data 
    


# TEST
for key,item in renteutgifter(2000000,4,240,"%").items():
    print(f"{key}: {item}")
# Out:
# Input Data:
# ------
# loan: 2000000
# rente: 4%
# terminer: 240
#
# Avdrag: 8333.333333333334
# Rentesats: 0.0033333333333333335
# Rente: [6666.666666666667, 6638.88888888889, 6611.111111111111, 6583.333333333334, 6555.555555555557, 6527.777777777778, 6500.0, 6472.222222222223, 6444.444444444444, 6416.666666666667, 6388.88888888889, 6361.111111111111, 6333.333333333334, 6305.555555555557, 6277.777777777778, 6250.0, 6222.222222222223, 6194.444444444444, 6166.666666666667, 6138.88888888889, 6111.111111111111, 6083.333333333334, 6055.555555555557, 6027.777777777778, 6000.0, 5972.222222222223, 5944.444444444444, 5916.666666666667, 5888.88888888889, 5861.111111111111, 5833.333333333334, 5805.555555555557, 5777.777777777778, 5750.0, 5722.222222222222, 5694.444444444444, 5666.666666666667, 5638.888888888889, 5611.111111111111, 5583.333333333334, 5555.555555555556, 5527.777777777778, 5500.0, 5472.222222222222, 5444.444444444444, 5416.666666666667, 5388.888888888889, 5361.111111111111, 5333.333333333334, 5305.555555555556, 5277.777777777778, 5250.0, 5222.222222222222, 5194.444444444444, 5166.666666666667, 5138.888888888889, 5111.111111111111, 5083.333333333334, 5055.555555555556, 5027.777777777778, 5000.0, 4972.222222222222, 4944.444444444444, 4916.666666666667, 4888.888888888889, 4861.111111111111, 4833.333333333334, 4805.555555555556, 4777.777777777777, 4750.0, 4722.222222222222, 4694.444444444444, 4666.666666666667, 4638.888888888889, 4611.111111111111, 4583.333333333334, 4555.555555555556, 4527.777777777777, 4500.0, 4472.222222222222, 4444.444444444444, 4416.666666666667, 4388.888888888889, 4361.111111111111, 4333.333333333334, 4305.555555555556, 4277.777777777777, 4250.0, 4222.222222222222, 4194.444444444444, 4166.666666666667, 4138.888888888889, 4111.111111111111, 4083.3333333333335, 4055.555555555555, 4027.777777777778, 4000.0000000000005, 3972.222222222222, 3944.4444444444443, 3916.666666666667, 3888.8888888888887, 3861.1111111111113, 3833.3333333333335, 3805.555555555555, 3777.777777777778, 3750.0000000000005, 3722.2222222222217, 3694.4444444444443, 3666.666666666667, 3638.8888888888887, 
222222223, 4340.277777777777, 4333.333333333334, 4326.388888888889, 4319.444444444445, 4312.5, 4305.555555555556, 4298.611111111111, 4291.666666666666, 4284.722222222223, 4277.777777777777, 4270.833333333334, 4263.888888888889, 4256.944444444445, 4250.0, 4243.055555555556, 4236.111111111111, 4229.166666666666, 4222.222222222223, 4215.277777777777, 4208.333333333334, 4201.388888888889, 4194.444444444445, 4187.5, 4180.555555555556, 4173.611111111111, 4166.666666666666, 4159.722222222223, 4152.777777777777, 4145.833333333334, 4138.888888888889, 4131.944444444445, 4125.0, 4118.055555555556, 4111.111111111111, 4104.166666666666, 4097.222222222223, 4090.277777777778, 4083.333333333333, 4076.3888888888887, 4069.4444444444443, 4062.5, 4055.5555555555557, 4048.6111111111113, 4041.666666666667, 4034.722222222222, 4027.777777777778, 4020.833333333333, 4013.8888888888887, 4006.9444444444443, 4000.0, 3993.0555555555557, 3986.1111111111113, 3979.166666666667, 3972.222222222222, 3965.277777777778, 3958.3333333333335, 3951.3888888888887, 3944.4444444444443, 3937.5, 3930.5555555555557, 3923.6111111111113, 3916.6666666666665, 3909.722222222222, 3902.777777777778, 3895.8333333333335, 3888.8888888888887, 3881.9444444444443, 3875.0, 3868.0555555555557, 3861.1111111111113, 3854.1666666666665, 3847.222222222222, 3840.277777777778, 3833.3333333333335, 3826.3888888888887, 3819.4444444444443, 3812.5, 3805.5555555555557, 3798.6111111111113, 3791.6666666666665, 3784.722222222222, 3777.777777777778, 3770.8333333333335, 3763.8888888888887, 3756.9444444444443, 3750.0, 3743.0555555555557, 3736.1111111111113 ...

# %% [markdown]
# c) Vis hva det samme lånet koster som annuitetslån, dvs differansen mellom alle terminbeløp og lånebeløp.<br> <br> Annuitetslån gir like terminbeløp hver måned, men renten utgjør en større del av dette beløpet i starten. Terminbeløpet for et annuitetslån er definert ved formelen:
# $T = x*\frac{r/f} {(1-(1+(r/f))^{-t})}$, hvor x=lånebeløp, r = årlig rente, t = terminer, f= antall forrentinger

# %%
def Annuitet(loan:int,rente:float,terminer:int,rente_format:str="desimal"):
    if rente_format == "percent" or rente_format == "%":
        rente = rente/100
    avdragsbeløp = loan/terminer
    rentesats  = rente/12
    terminbeløp = loan*(((rente+1)/terminer)/(1-(1+((rente+1)/terminer))**-terminer))
    rente_list = []
    avdrags_list = []
    
    for termin in range(1,terminer+1):
        current_value = (loan - avdragsbeløp*(termin-1))
        rente_list.append(current_value*rentesats)
        avdrags_list.append(terminbeløp-rente_list[-1])
    

    data = {"Input Data": f"\n------\nloan: {loan}\nrente: {int((rente)*100)}%\nterminer: {terminer}\n",
            "Terminbeløp":terminbeløp,"Rentesats":rentesats,"Rente":rente_list,"Avdrag":avdrags_list}

    return data 
    

for year in [10,20,30]:
    print("-"*20,"\n")
    print(f"YEAR - {year}\n")
    for key,item in Annuitet(1000000,3,year*12,"%").items():
        print(f"\n{key}: {item}")
    print("\n")
# Out:
# --------------------
#
# YEAR - 10
#
#
# Input Data:
# ------
# loan: 1000000
# rente: 3%
# terminer: 120
#
#
# Terminbeløp: 13381.758376933554
#
# Rentesats: 0.0025
#
14902789399, 2731.093472338435, 2738.037916782879, 2744.982361227324, 2751.9268056717683, 2758.8712501162127, 2765.815694560657, 2772.7601390051013, 2779.7045834495457, 2786.64902789399, 2793.593472338435, 2800.537916782879, 2807.482361227324, 2814.4268056717683, 2821.3712501162127, 2828.315694560657, 2835.2601390051013, 2842.2045834495457, 2849.14902789399, 2856.093472338435, 2863.037916782879, 2869.982361227324, 2876.9268056717683, 2883.8712501162127, 2890.815694560657, 2897.7601390051013, 2904.7045834495457, 2911.64902789399, 2918.593472338435, 2925.537916782879, 2932.482361227324, 2939.4268056717683, 2946.3712501162127, 2953.315694560657, 2960.2601390051013, 2967.2045834495457, 2974.14902789399, 2981.093472338435, 2988.037916782879, 2994.982361227324, 3001.9268056717683, 3008.8712501162127, 3015.815694560657, 3022.7601390051013, 3029.7045834495457, 3036.64902789399, 3043.593472338435, 3050.537916782879, 3057.482361227324, 3064.4268056717683, 3071.3712501162127, 3078.315694560657, 3085.2601390051013, 3092.2045834495457, 3099.14902789399, 3106.093472338435, 3113.037916782879, 3119.982361227324, 3126.9268056717683, 3133.8712501162127, 3140.815694560657, 3147.7601390051013, 3154.7045834495457, 3161.64902789399, 3168.593472338435, 3175.537916782879, 3182.482361227324, 3189.4268056717683, 3196.3712501162127, 3203.315694560657, 3210.2601390051013, 3217.2045834495457, 3224.14902789399, 3231.093472338435, 3238.037916782879, 3244.982361227324, 3251.9268056717683, 3258.8712501162127, 3265.815694560657, 3272.7601390051013, 3279.7045834495457, 3286.6490278939905, 3293.593472338435, 3300.537916782879, 3307.4823612273235, 3314.4268056717683, 3321.3712501162127, 3328.315694560657, 3335.2601390051013, 3342.2045834495457, 3349.1490278939905, 3356.093472338435, 3363.037916782879, 3369.982 ...

# %% [markdown]
# c) Vis hvordan utviklingen i rentekostnader og avdrag på terminer for serielån grafisk ved hjelp av stackplot funksjonen i matplotlib. Anta et bankinnskudd x = 1 000 000 kr, årlig rente r=3% og antall terminer t = 240 (det vil si 20 år). Siden vi må vise utviklingen per termin, husk at "t" også definerer hvilken måned vi er i. Dvs, hvis t=15, har det gått 1 år og 3 mnd med terminer. Se forøvrig relevante formler i oppgave (a)
#
# <br>
#
# <b>Hint1:</b> Siden avdragene er like for alle måneder, kan det være lurt å definere det månedlige avdraget som en liste og gange det med antall perioder.
# <b>Hint2:</b> Siden vi er ute etter både rentekostnader og avdrag hver for seg, kan det være lurt å definere en funksjon for hver av dem.

# %%
termin_linspace = np.linspace(0,240,240)
renteutgift = dict(renteutgifter(1000000,3,240,"%"))
anu = Annuitet(1000000,3,240,"%")
avdrag_list = []
for x in range(0,240):
    avdrag_list.append(renteutgift["Avdrag"])

label = ["Avdrag","Rente"]
    
plt.stackplot(termin_linspace,avdrag_list,renteutgift["Rente"],labels=label,colors=["#ffa822","#ff9d0a80"])
plt.suptitle("serielån grafisk",x=0.13,y=0.95,size=14,weight='bold')
plt.title(f"Avdrag = constant({int(float(renteutgift['Avdrag']))})",loc="left",size=10)
plt.subplots_adjust(top=0.85)
plt.xlabel("Termin")
plt.ylabel("Payment")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),ncol=5)
